# %% [markdown]
# # Realtime recording and plot for checking performance

# %% [markdown]
# ## Import

# %%
from interfaces.control_socket_client import ControlSocketClient
from utils.record_plot import *

step_ip = '192.168.5.115'
control = ControlSocketClient(step_ip)

# %% [markdown]
# ## Load data from STEP
# * record = load_data_6dof(step_ip, file_name)
# * record = load_data_7dof(step_ip, file_name)

# %%
plot = PlotTool(control)
# plot = PlotTool()

# %%
file_name = 'RTRecord.csv'
record = plot.load_data_6dof(file_name, step_ip)

# record = load_data_7dof(file_name, step_ip)

# %% [markdown]
# ## Plot result
# * plot_joint(record)
# * plot_task(record)

# %%
plot.plot_joint_pos()

# %%
plot.plot_joint_pos(unit='deg')

# %%
plot.plot_joint_pos(unit='deg')

# %%
plot.plot_joint_vel(unit='deg')

# %%
plot.plot_joint_vel(unit='deg')

# %%
plot.plot_joint_acc(unit='deg')

# %%
plot.plot_joint_acc(unit='deg')

# %% [markdown]
# ## Max, Min, RMS error

# %%
return fabs(INDY_JACC_BOUNDARIES[jIdx].min()) + accGap * accRatio;

# %%
gap = 300 - 18
print(gap)
18 + gap*9

# %% [markdown]
# ## Manual recording timing

# %%
start_log()

# %%
end_log()
